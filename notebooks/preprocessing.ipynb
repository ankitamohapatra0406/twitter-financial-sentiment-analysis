# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
from preprocess import clean_text
import pandas as pd

# %%
raw_df = pd.read_csv("../data/raw/stockerbot-export1.csv")
raw_df['clean_text'] = raw_df['text'].apply(clean_text)

# %%
label_df.columns
# Out:
# Index(['cleaned_tweets', 'sentiment'], dtype='object')

# %%
label_df = pd.read_csv("../data/labeled/tweet_sentiment.csv")
label_df.rename(columns={'cleaned_tweets': 'clean_text'}, inplace=True)
label_df.head()
# Out:
#                                           clean_text  sentiment
# 0  video offic mind busi david solomon tell gs in...          0
# 1  price lumber lb f sinc hit ytd high maci turna...          0
# 2                            say american dream dead         -1
# 3  barri silbert extrem optimist bitcoin predict ...          1
# 4  satellit avoid attack space junk circl earth paid         -1

# %%
raw_df.to_csv("../data/processed_raw.csv", index=False)
label_df.to_csv("../data/processed_labeled.csv", index=False)
