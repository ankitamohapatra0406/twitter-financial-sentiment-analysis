# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
from sentiment_model import predict_sentiment
import pandas as pd

# %%
df = pd.read_csv("../data/processed_raw.csv")

# %%
df['clean_text'] = df['clean_text'].astype(str)
df['predicted_sentiment'] = df['clean_text'].apply(predict_sentiment)

# %%
df['predicted_sentiment'].value_counts()
# Out:
# predicted_sentiment
# Neutral     16965
# Positive     7715
# Negative     3760
# Name: count, dtype: int64

# %%
df.to_csv("../data/final_with_sentiment.csv", index=False)
